# %% [markdown]
# <a href="https://colab.research.google.com/github/susmoy15/Machine_Learning/blob/main/Fetching_data_from_an_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2      238             The Godfather
# 3   687163         Project Hail Mary
# 4      240     The Godfather Part II
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    328.7016
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     71.0607
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     47.9630
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    402.5239
# 4  In the continuing saga of the Corleone crime f...   1974-12-20     28.1317
#
#    vote_average  vote_count
# 0         8.969        1382
# 1         8.721       30402
# 2         8.686       22940
# 3         8.600        4101
# 4         8.571       13907

# %%
df = pd.DataFrame()         #empty dataframe

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#             id                           title  \
# 0      1007757                         Swapped
# 1          278        The Shawshank Redemption
# 2          238                   The Godfather
# 3       687163               Project Hail Mary
# 4          240           The Godfather Part II
# ...        ...                             ...
# 15515   121824                   Stand Up Guys
# 15516    11777                            I.Q.
# 15517   431075                        Polaroid
# 15518   378018                        The Void
# 15519    21301  Barbershop 2: Back in Business
#
#                                                 overview release_date  \
# 0      A small woodland creature and a majestic bird,...   2026-05-01
# 1      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3      Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# ...

# %%
df.shape
# Out:
# (15520, 7)

# %%
df.to_csv('movies.csv')
